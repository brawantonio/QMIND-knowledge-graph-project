# %%
import pandas as pd
import numpy as np
from IPython.display import display

from gensim.models.doc2vec import Doc2Vec, TaggedDocument

import re
import nltk
import string
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('wordnet')

# Instantiate stopWords
stopWords = stopwords.words("english")
    
# Instantiate wordnet lemmatizer
wn = nltk.WordNetLemmatizer()

from sklearn.decomposition import PCA
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\denni\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\denni\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
"""
Desc: Standard preprocessing of query
Input: query (string) - text to be cleaned
Output: query (list of string) - cleaned text
"""
def preproc_query(query):
    
    # Lower case
    query = query.lower()

    # Remove unicode characters (emojis, etc.)
    query = query.encode('ascii', 'ignore').decode('utf-8')

    # Reduce repeated letters
    query= re.sub(re.compile(r"(.)\1{2,}"), r"\1\1", query)

    # Remove stop words
    pat = r'\b(?:{})\b'.format('|'.join(stopWords))
    query = re.sub(pat, '', query)

    # Remove punctuation
    query = re.sub('[%s]' % re.escape(string.punctuation), ' ', query)

    # Remove stop words again (in case stop word was next to punctuation)
    query = re.sub(pat, '', query)

    # Remove extra blank spaces
    query = re.sub(r'\s{2,}', ' ', query)

    # Lemmatize and tokenize
    query = [wn.lemmatize(word) for word in query.split()]
    
    return query

# %%
# Load data
df = pd.read_csv("kingston_clean.csv", usecols=["url", "clean_text"])

# Display
display(df.head())
print(len(df.index))
# Out:
#                                                  url  \
# 0                     https://www.cityofkingston.ca/
# 1  https://www.cityofkingston.ca/residents/commun...
# 2  https://www.cityofkingston.ca/residents/commun...
# 3  https://www.cityofkingston.ca/residents/commun...
# 4  https://www.cityofkingston.ca/residents/commun...
#
#                                           clean_text
# 0   home city kingston navigation skip content sk...
# 1   poverty reduction city kingston navigation sk...
# 2   ontario work city kingston navigation skip co...
# 3   municipal fee assistance program city kingsto...
# 4   housing city kingston navigation skip content...
# 10689

# %%
# Build bag of words and tokens
text_docs = [TaggedDocument(doc.split(' '), [i]) 
             for i, doc in enumerate(df["clean_text"])]

# %%
# %%time

# Instantiate model
model = Doc2Vec(vector_size=64, window=2, min_count=1, workers=8, epochs=40)

# Build vocab
model.build_vocab(text_docs)

# Train model
model.train(text_docs, total_examples=model.corpus_count, epochs=model.epochs)

# Generate vectors
text2vec = [model.infer_vector((df['clean_text'][i].split(' '))) for i in range(0,len(df['clean_text']))]

# Set list to dataframe column
df['text_vec'] = np.array(text2vec).tolist()

# Display
display(df.head())
# Out:
#                                                  url  \
# 0                     https://www.cityofkingston.ca/
# 1  https://www.cityofkingston.ca/residents/commun...
# 2  https://www.cityofkingston.ca/residents/commun...
# 3  https://www.cityofkingston.ca/residents/commun...
# 4  https://www.cityofkingston.ca/residents/commun...
#
#                                           clean_text  \
# 0   home city kingston navigation skip content sk...
# 1   poverty reduction city kingston navigation sk...
# 2   ontario work city kingston navigation skip co...
# 3   municipal fee assistance program city kingsto...
# 4   housing city kingston navigation skip content...
#
#                                             text_vec
# 0  [1.3450957536697388, -0.1454906463623047, -0.0...
# 1  [1.7279950380325317, 0.807035505771637, -1.771...
# 2  [2.4424219131469727, 3.1754353046417236, 1.267...
# 3  [0.7618685960769653, 1.3048862218856812, 1.570...
# 4  [1.2927143573760986, 0.23918530344963074, 0.44...
# Wall time: 5min 42s

# %%
# Save model
model.save("doc2vec_kingston")

# %%
# Convert string to vec
query = "Queen's university"

query = preproc_query(query)

query = model.infer_vector(query)

# Convert to np array
query = np.array(query)

print(query)
# Out:
# [ 0.31971943 -0.13755491 -0.17359641 -0.42708182 -0.05357218 -0.1644662
#   0.25183767  0.3060779   0.23542143  0.38607714 -0.21343933 -0.24547648
#  -0.2937509   0.00665796  0.03709129 -0.07275939  0.26697975  0.38631687
#  -0.08295317 -0.15205279 -0.19144835 -0.00707507  0.09481531 -0.09329452
#   0.31234917 -0.52970743  0.10058472 -0.25680634 -0.20257765  0.09781083
#  -0.2603708  -0.23708706 -0.39939818 -0.12630107  0.32891896 -0.1431428
#   0.20999627 -0.22820976  0.06280139 -0.19122955  0.03298479 -0.15545866
#  -0.1962802   0.14430775 -0.18865132 -0.22804849 -0.11102099  0.02391251
#   0.02678386 -0.31591177  0.01975598 -0.39699438 -0.45853597 -0.20703813
#  -0.15655391 -0.36821085  0.31201756 -0.13861892 -0.08253559 -0.5097666
#  -0.17030211 -0.1944427  -0.1106058  -0.14506228]

# %%
# Compute cosine similarity between query and text vectors
df["cos_dist"] = df["text_vec"].apply(lambda x: np.dot(query, np.array(x)) / 
                                      (np.linalg.norm(query) * np.linalg.norm(np.array(x))))

# Display
display(df.head())
# Out:
#                                                  url  \
# 0                     https://www.cityofkingston.ca/
# 1  https://www.cityofkingston.ca/residents/commun...
# 2  https://www.cityofkingston.ca/residents/commun...
# 3  https://www.cityofkingston.ca/residents/commun...
# 4  https://www.cityofkingston.ca/residents/commun...
#
#                                           clean_text  \
# 0   home city kingston navigation skip content sk...
# 1   poverty reduction city kingston navigation sk...
# 2   ontario work city kingston navigation skip co...
# 3   municipal fee assistance program city kingsto...
# 4   housing city kingston navigation skip content...
#
#                                             text_vec  cos_dist
# 0  [1.3450957536697388, -0.1454906463623047, -0.0...  0.626713
# 1  [1.7279950380325317, 0.807035505771637, -1.771...  0.388114
# 2  [2.4424219131469727, 3.1754353046417236, 1.267...  0.295472
# 3  [0.7618685960769653, 1.3048862218856812, 1.570...  0.368819
# 4  [1.2927143573760986, 0.23918530344963074, 0.44...  0.450808

# %%
# Sort df
df = df.sort_values(by=["cos_dist"], ascending=False, ignore_index=True)

# Take top N results
df = df.head(100)

# Display
display(df)
# Out:
#                                                   url  \
# 0   https://www.cityofkingston.ca/documents/10180/...
# 1   https://www.cityofkingston.ca/documents/10180/...
# 2   https://www.cityofkingston.ca/documents/10180/...
# 3   https://www.cityofkingston.ca/documents/10180/...
# 4   https://www.cityofkingston.ca/documents/10180/...
# ..                                                ...
# 95  https://www.cityofkingston.ca/documents/10180/...
# 96  https://www.cityofkingston.ca/documents/10180/...
# 97  https://www.cityofkingston.ca/documents/10180/...
# 98  https://www.cityofkingston.ca/documents/10180/...
# 99  https://www.cityofkingston.ca/documents/10180/...
#
#                                            clean_text  \
# 0    city kingston file available file available f...
# 1    city kingston file available file available f...
# 2    city kingston file available file available f...
# 3    city kingston file available file available f...
# 4    city kingston file available file available f...
# ..                                                ...
# 95   city kingston file available file available f...
# 96   city kingston file available file available f...
# 97   city kingston file available file available f...
# 98   city kingston file available file available f...
# 99   city kingston file available file available f...
#
# https://www.cityofkingston.ca/documents/10180/10688411/COU_A2115-15371.pdf/2f2523c4-5c86-440d-b911-00a249759c08
# https://www.cityofkingston.ca/documents/10180/9710729/COU_A1715-15290.pdf/4b0fe0ef-d68f-4c3c-8c32-9b86689419ed
# https://www.cityofkingston.ca/documents/10180/9710729/COU_A1715-ARCP65.pdf/020ad96a-1b23-44e6-9a9f-b7ea39fdd9c0
# https://www.cityofkingston.ca/documents/10180/221369/COU_A2312-12330.pdf/4d6b1969-1a61-4793-95c1-8e3eca081279
# https://www.cityofkingston.ca/documents/10180/138034/COU_A0613-13104.pdf/3989ec8f-5413-4b53-8aba-0b96c9354eb5
# https://www.cityofkingston.ca/documents/10180/1542724/COU_A1713-13246.pdf/a8f15238-7682-491f-8a02-26f86ab9fb56
# https://www.cityofkingston.ca/documents/10180/11849298/COU_A0116-16007.pdf/af78ee80-8954-40b3-bdd2-b88940c493d0
# https://www.cityofkingston.ca/documents/10180/11058901/PLN_A1615-15120.pdf/d7f24b78-5bed-4992-b749-c8c17e0fcb47
# https://www.cityofkingston.ca/documents/10180/9204252/MAAC_A0515-SchedA.pdf/26b46f57-5c8a-4507-ba4c-764fe217efd8
# https://www.cityofkingston.ca/documents/10180/1871843/COU_Agenda-1813AD.pdf/8eea1c2c-527d-4b00-98b5-329687a8b539

# %%
# Perform PCA to reduce dimensions to 2
# Initialize PCA
pca = PCA(2)
 
# Transform the data
df_vec = pd.DataFrame(df["text_vec"].to_list())

# Convert to dataframe
df_vec = pd.DataFrame(pca.fit_transform(df_vec), columns=['pca_x', 'pca_y'])

# Normalize pca dimensions to [0, 1]
df_vec["pca_x"] = (df_vec["pca_x"] - df_vec["pca_x"].min()) / (df_vec["pca_x"].max() - df_vec["pca_x"].min()) 
df_vec["pca_y"] = (df_vec["pca_y"] - df_vec["pca_y"].min()) / (df_vec["pca_y"].max() - df_vec["pca_y"].min())

# Concatenate df_vec to df
df = pd.concat([df, df_vec], axis=1)

# Select columns
df = df[["url", "pca_x", "pca_y", "cos_dist"]]

# Display
display(df)
# Out:
#                                                   url     pca_x     pca_y  \
# 0   https://www.cityofkingston.ca/documents/10180/...  0.396034  0.279686
# 1   https://www.cityofkingston.ca/documents/10180/...  0.259847  0.470561
# 2   https://www.cityofkingston.ca/documents/10180/...  0.411407  0.383228
# 3   https://www.cityofkingston.ca/documents/10180/...  0.921991  0.406916
# 4   https://www.cityofkingston.ca/documents/10180/...  0.690915  0.559389
# ..                                                ...       ...       ...
# 95  https://www.cityofkingston.ca/documents/10180/...  0.413022  0.573016
# 96  https://www.cityofkingston.ca/documents/10180/...  0.465175  0.692867
# 97  https://www.cityofkingston.ca/documents/10180/...  0.155057  0.356693
# 98  https://www.cityofkingston.ca/documents/10180/...  0.246449  0.302546
# 99  https://www.cityofkingston.ca/documents/10180/...  0.232390  0.373787
#
#     cos_dist
# 0   0.950235
# 1   0.946684
# 2   0.943909
# 3   0.943192
# 4   0.941597
# ..       ...
# 95  0.929740
# 96  0.929726
# 97  0.929601
# 98  0.929357
# 99  0.929274
#
# [100 rows x 4 columns]

# %%
# Save final result to csv
df.to_csv("query_results.csv", index=False)
